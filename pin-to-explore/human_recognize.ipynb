# %% [markdown]
# # Gemini Human Recognize

# %%
# %pip install --upgrade --quiet google-genai pillow dotenv pandas
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv
import os

load_dotenv()
# Out:
# True

# %%
PROJECT_ID = os.environ['PROJECT_ID']
LOCATION = os.environ['LOCATION']
GS_BUCKET = os.environ['GS_BUCKET']
BUCKET = os.environ['BUCKET']

# %%
MODEL_ID= "gemini-2.0-flash-001"

# %%
from google import genai
from google.genai import types
from google.genai.types import (
    GenerateContentConfig,
    GoogleSearch,
    Part,
    Tool,
)
from IPython.display import HTML, Markdown, display

# %%
client = genai.Client(vertexai=True, project=PROJECT_ID, location=LOCATION)

# %%
def detect_with_gemini(image_path):
    #system_instruction="You are an image analysis AI. You can identify people in images and provide their names"
    system_instruction="당신은 이미지 분석하는 일을 담당합니다. 주어진 이미지에서 인물을 찾아서 인물의 이름을 알려주세요. 인물이 누구인지 모르거나, 100% 신뢰할 수 없다면 '모름'으로 답하세요."

    google_search_tool = Tool(google_search=GoogleSearch())

    grounding_config = GenerateContentConfig(
        temperature = 0.1,
        top_p = 0.99,
        max_output_tokens = 8192,
        response_modalities = ["TEXT"],
        system_instruction=system_instruction,
        tools=[google_search_tool]   
    )

    #prompt = f"""If you can identify the people in the image, provide their names ONLY. If you don't know them, Don't make up names and just respond with 'unknown'"""
    prompt = f"""설명을 붙이지 말고, 이름만 대답하세요."""

    with open(image_path, "rb") as f:
        image = f.read()

    response = client.models.generate_content(
        model=MODEL_ID,
        contents=[Part.from_bytes(data=image, mime_type="image/png"),
            prompt,],
        config=grounding_config
    )

    print(response.text)

# %%
def detect_with_gemini_url(image_path, percent):
    #system_instruction="You are an image analysis AI. You can identify people in images and provide their names"
    system_instruction=f"당신은 이미지 분석하는 일을 담당합니다. 주어진 이미지에서 인물을 찾아서 인물의 이름을 알려주세요. 인물이 누구인지 모르거나, {percent}% 신뢰할 수 없다면 '모름'으로 답하세요."

    google_search_tool = Tool(google_search=GoogleSearch())

    grounding_config = GenerateContentConfig(
        temperature = 0.1,
        top_p = 0.99,
        max_output_tokens = 8192,
        response_modalities = ["TEXT"],
        system_instruction=system_instruction,
        tools=[google_search_tool]   
    )

    #prompt = f"""If you can identify the people in the image, provide their names ONLY. If you don't know them, Don't make up names and just respond with 'unknown'"""
    prompt = f"""설명을 붙이지 말고, 이름만 대답하세요."""


    response = client.models.generate_content(
        model=MODEL_ID,
        contents=[Part.from_uri(file_uri=f"{GS_BUCKET}/human_images/{image_path}", mime_type="image/jpeg"),
            prompt,],
        config=grounding_config
    )

    print(response.text)
    return response.text

# %% [markdown]
# ## Vision

# %%
# %pip install google-cloud-vision

# %%
from google.cloud import vision

# %%
vision_client = vision.ImageAnnotatorClient()

# %%
def detect_with_vision(image_path):
    with open(image_path, "rb") as f:
        image = f.read()
    vision_image = vision.Image(content=image)
    web_detection = vision_client.web_detection(image=vision_image).web_detection
    results = [d.description for d in web_detection.web_entities]
    print(results)

# %% [markdown]
# <img src=./human1.png width="10%">

# %%
detect_with_gemini("human1.png")
# Out:
# 모름

# %%
detect_with_vision("human1.png")
# Out:
# ['Yoon Suk Yeol', 'Myung Tae-kyun', 'Newstapa', '2024 South Korean martial law crisis', 'Journalism', 'People Power Party', 'Investigative journalism', 'Korea exploration Journalism Center', '주간뉴스타파', 'Reporter']

# %% [markdown]
# <img src=./human3.png width="10%">

# %%
detect_with_gemini("human3.png")
# Out:
# 모름

# %%
detect_with_vision("human3.png")
# Out:
# ['Lee Yi-kyung', 'Song Eun-yi', 'Kwon Il-yong', 'Brave Detectives', 'Detective', 'Criminal investigation', 'Television', 'MyDramaList', 'Crime', 'Netflix']

# %% [markdown]
# <img src=./human5.png width="10%">

# %%
detect_with_gemini("human5.png")
# Out:
# 모름

# %%
detect_with_vision("human5.png")
# Out:
# ['Kim Bu-gyeom', 'Politics', 'Minister', 'Member of the National Assembly of the Republic of Korea', 'General election', '2020 South Korean legislative election', 'Election law', 'Legislative elections in South Korea']

# %% [markdown]
# <img src="./human4.png" width="10%">

# %%
detect_with_gemini("human4.png")
# Out:
# 모름

# %%
detect_with_vision("human4.png")
# Out:
# ['Lee Yeon-bok', 'Please Take Care of My Refrigerator', 'Kim Seong-joo', '냉장고를 부탁해 2', 'JTBC', 'Variety show', 'Refrigerator', 'Television', '2014', 'MyDramaList']

# %% [markdown]
# <img src=./human6.png width="10%">

# %%
detect_with_gemini("human6.png")
# Out:
# 이선균, 아이유

# %%
detect_with_vision("human6.png")
# Out:
# ['IU', 'Lee Sun-kyun', 'My Mister', 'Times Square, Seoul', '데일리안', 'tvN', 'Actor', 'Photograph', 'Laughter', 'tvN DRAMA']

# %%
import pandas as pd
from IPython.display import display, HTML

def display_dataframe_with_images(df):

    html = df.copy()
    html = html.to_html(escape=False, index=False)

    display(HTML(html))

# %%
df = pd.DataFrame(columns=['image', 'name_100%', 'name_90%', 'name_80%'])

for i in range(1,69):
    names_100 = detect_with_gemini_url(f"image_{i}.jpeg", 100)
    names_90 = detect_with_gemini_url(f"image_{i}.jpeg", 90)
    names_80 = detect_with_gemini_url(f"image_{i}.jpeg", 80)
    image_data = f"<img src=\"https://storage.googleapis.com/{BUCKET}/human_images/image_{i}.jpeg\" width=\"40%\"/>"
    new_row = pd.DataFrame({'image': [image_data], 'name_100%': [names_100], 'name_90%': [names_90], 'name_80%': [names_80]})
    df = pd.concat([df, new_row], ignore_index=True)
# Out:
# 성룡
#
# 성룡
#
# 성룡
#
# 윤여정
#
# 윤여정
#
# 윤여정
#
# 레오나르도 디카프리오
#
# 레오나르도 디카프리오
#
# 레오나르도 디카프리오
#
# 양세형
#
# 제이쓴
#
# 모름
# 김수현
#
# 김수현
#
# 김수현
#
# 스티브 잡스
#
# 스티브 잡스
#
# 스티브 잡스
#
# 모름
#
# 모름
#
# 모름
#
# 다음은 이미지에 있는 인물의 이름입니다.
#
# 신하균, 김고은
#
# 조승우, 송지효
#
# 조승우, 송지효
#
# 박원순
#
# 박원순
#
# 박원순
#
# 문재인
#
# 문재인
#
# 문재인
#
# 넬슨 만델라
#
# 넬슨 만델라
#
# 넬슨 만델라
#
# 모름
# 모름
#
# 김혜수
#
# 패리스 힐튼
#
# 패리스 힐튼
#
# 패리스 힐튼
#
# 모름
#
# 모름
#
# 모름
# 송지효
#
# 송지효
#
# 송지효
#
# 옥택연
#
# 옥택연
#
# 옥택연
#
# 모름
#
# 모름
#
# 모름
#
# 차은우
#
# 차은우
#
# 차은우
#
# 배두나
#
# 다음과 같은 검색어를 사용해서 정보를 찾아보겠습니다:
#
#  죄송합니다. 이미지 속 인물이 누구인지 확실하게 식별할 수 없습니다.
# 김선영
#
# 일론 머스크
#
# 일론 머스크
#
# 일론 머스크
#
# 조 바이든
#
# 조 바이든
#
# 조 바이든
#
# 모름
#
# 이름을 확인하기 위해 검색을 해보겠습니다.
# 강호동
#
# 모름
#
# 시진핑
#
# 시진핑
#
# 시진핑
#
# 강호동
#
# 강호동
#
# 강호동
#
# 모름
#
# 모름
#
# 모름
#
# 유재석
#
# 유재석
#
# 유재석
#
# 김선호
#
# 김선호
#
# 김선호
#
# 유아인
#
# 유아인
#
# 유아인
#
# 전현무
#
# 전현무
#
# 전현무
#
# 제니퍼 로페즈
#
# 제니퍼 로페즈
#
# 제니퍼 로페즈
#
# 싸이, 손연재, 류승룡
#
# 싸이, 손연재, 류승룡
#
# 싸이, 손연재, 류승룡
#
# 모름
# 모름
#
# 모름
#
# 버락 오바마
#
# 버락 오바마
#
# 버락 오바마
#
# 모름
#
# 모름
#
# 모름
#
# 전지현
#
# 전지현
#
# 전지현
#
# 유아인
#
# 유아인
#
# 유아인
#
# Warren Buffett
#
# 워렌 버핏
#
# 워렌 버핏
#
# 모름
#
# 모름
#
# 저우둥위 (周冬雨)
#
# 한소희
#
# 한소희
#
# 한소희
#
# 패리스 힐튼
#
# 파리스 힐튼
#
# 파리스 힐튼
#
# 소지섭
#
# 소지섭
#
# 소지섭
#
# 벤 매켄지
#
# 벤 맥켄지
#
# 벤 맥켄지
#
# 모름
#
# 모름
#
# 모름
#
# 모름
# 최지우
#
# 김희애
#
# 모름
#
# 모름
#
# 모름
#
# 소지섭
#
# 소지섭
#
# 소지섭
#
# 모름
# 이해찬
#
# 김부겸
#
# 모름
#
# 모름
#
# 모름
#
# 뷔
#
# 뷔
#
# 뷔
#
# 모름
#
# 김현중
#
# 김현중
#
# 조지 클루니
#
# 조지 클루니
#
# 조지 클루니
#
# 모름
#
# 모름
#
# 모름
#
# 제니
#
# 제니
#
# 제니
#
# 모름
#
# 모름
#
# 모름
#
# 마이클 잭슨
#
# 마이클 잭슨
#
# 마이클 잭슨
#
# 모름
#
# 모름
# 모름
# 모름
# 박찬호
#
# 모름
# 손흥민
#
# 손흥민
#
# 손흥민
#
# 송해
# 홍현희
#
# 송해
# 리즈 위더스푼
#
# 리즈 위더스푼
#
# 리즈 위더스푼
#
# 판빙빙
#
# 판빙빙
#
# 판빙빙
#
# 타이거 우즈
#
# 타이거 우즈
#
# 타이거 우즈
#
# 조상기
#
# 모름
#
# 모름
# 김정은
#
# 김정은
#
# 김정은
#
# 이준석
#
# 이준석
#
# 이준석
#
# 정우성
#
# 정우성
#
# 정우성
#
# 송중기, 고민시
#
# 송중기, 고민시
#
# 송중기, 고민시
#
# 알베르트 아인슈타인
#
# 알베르트 아인슈타인
#
# 알베르트 아인슈타인

# %%
display_dataframe_with_images(df)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>image</th>
#       <th>name_100%</th>
#       <th>name_90%</th>
#       <th>name_80%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td><img src="https://storage.googleapis.com/lge_tv/human_images/image_1.jpeg" width="40%"/></td>
#       <td>성룡\n</td>
#       <td>성룡\n</td>
#       <td>성룡\n</td>
#     </tr>
#     <tr>
#       <td><img src="https://storage.googleapis.com/lge_tv/human_images/image_2.jpeg" width="40%"/></td>
#       <td>윤여정\n</td>
#       <td>윤여정\n</td>
#       <td>윤여정\n</td>
#     </tr>
#     <tr>
#       <td><img src="https://storage.googleapis.com/lge_tv/human_images/image_3.jpeg" width="40%"/></td>
#       <td>레오나르도 디카프리오\n</td>
#       <td>레오나르도 디카프리오\n</td>
#       <td>레오나르도 디카프리오\n</td>
#     </tr>
#     <tr>
#       <td><img src="https://storage.googleapis.com/lge_tv/human_images/image_4.jpeg" width="40%"/></td>
#       <td>양세형\n</td>
#       <td>제이쓴\n</td>
#       <td>모름</td>
#     </tr>
#     <tr>
#       <td><img src="https://storage.googleapis.com/lge_tv/human_images/image_5.jpeg" width="40%"/></td>
#       <td>김수현\n</td>
#       <td>김수현\n</td>
#       <td>김수현\n</td>
#     </tr>
#     <tr>
#       <td><img src="https://storage.googleapis.com/lge_tv/human_images/image_6.jpeg" width="40%"/></td>
#       <td>스티브 잡스\n</td>
#       <td>스티브 잡스\n</td>
#       <td>스티브 잡스\n</td>
#     </tr>
#     <tr>
#       <td><img src="https://storage.googleapis.com/lge_tv/human_images/image_7.jpeg" width="40%"/></td>
#       <td>모름\n</td>
#       <td>모름\n</td>
#       <td>모름\n</td>
#     </tr>
#     <tr>
#       <td><img src="https://storage.googleapis.com/lge_tv/human_images/image_8.jpeg" width="40%"/></td>
#       <td>다음은 이미지에 있는 인물의 이름입니다.\n\n신하균, 김고은\n</td>
#       <td>조승우, 송지효\n</td>
#       <td>조승우, 송지효\n</td>
#     </tr>
#     <tr>
#       <td><img src="https://storage.googleapis.com/lge_tv/human_images/image_9.jpeg" width="40%"/></td>
#       <td>박원순\n</td>
#       <td>박원순\n</td>
#       <td>박원순\n</td>
#     </tr>
#     <tr>
#       <td><img src="https://storage.googleapis.com/lge_tv/human_images/image_10.jpeg" width="40%"/></td>
#       <td>문재인\n</td>
#       <td>문재인\n</td>
#       <td>문재인\n</td>
#     </tr>
#     <tr>
#       <td><img src="https://storage.googleapis.com/lge_tv/human_images/image_11.jpeg" width="40%"/></td>
#       <td>넬슨 만델라\n</td>
#       <td>넬슨 만델라\n</td>
#       <td>넬슨 만델라\n</td>
#     </tr>
#     <tr>
#       <td><img src="https://storage.googleapis.com/lge_tv/human_images/image_12.jpeg" width="40%"/></td>
#       <td>모름</td>
#       <td>모름\n</td>
#       <td>김혜수\n</td>
#     </tr>
#     <tr>
#       <td><img src="https://storage.googleapis.com/lge_tv/human_images/image_13.jpeg" width="40%"/></td>
#       <td>패리스 힐튼\n</td>
#       <td>패리스 힐튼\n</td>
#       <td>패리스 힐튼\n</td>
#     </tr>
#     <tr>
#       <td><img src="https://storage.googleapis.com/lge_tv/human_images/image_14.jpeg" width="40%"/></td>
#       <td>모름\n</td>
#       <td>모름\n</td>
#       <td>모름</td>
#     </tr>
#     <tr>
#       <td><img src="https://storage.googleapis.com/lge_tv/human_images/image_15.jpeg" width="40%"/></td>
#       <td>송지효\n</td>
#       <td>송지효\n</td>
#       <td>송지효\n</td>
#     </tr>
#     <tr>
#       <td><img src="https://storage.googleapis.com/lge_tv/human_images/image_16.jpeg" width="40%"/></td>
#       <td>옥택연\n</td>
#       <td>옥택연\n</td>
#       <td>옥택연\n</td>
#     </tr>
#     <tr>
#       <td><img src="https://storage.googleapis.com/lge_tv/human_images/image_17.jpeg" width="40%"/></td>
#       <td>모름\n</td>
#       <td>모름\n</td>
#       <td>모름\n</td>
#     </tr>
#     <tr>
#       <td><img src="https://storage.googleapis.com/lge_tv/human_images/image_18.jpeg" width="40%"/></td>
#       <td>차은우\n</td>
#       <td>차은우\n</td>
#       <td>차은우\n</td>
#     </tr>
#     <tr>
#       <td><img src="https://storage.googleapis.com/lge_tv/human_images/image_19.jpeg" width="40%"/></td>
#       <td>배두나\n</td>
#       <td>다음과 같은 검색어를 사용해서 정보를 찾아보겠습니다:\n\n 죄송합니다. 이미지 속 인물이 누구인지 확실하게 식별할 수 없습니다.</td>
#       <td>김선영\n</td>
#     </tr>
#     <tr>
#       <td><img src="https://storage.googleapis.com/lge_tv/human_images/image_20.jpeg" width="40%"/></td>
#       <td>일론 머스크\n</td>
#       <td>일론 머스크\n</td>
#       <td>일론 머스크\n</td>
#     </tr>
#     <tr>
#       <td><img src="https://storage.googleapis.com/lge_tv/human_images/image_21.jpeg" width="40%"/></td>
#       <td>조 바이든\n</td>
#       <td>조 바이든\n</td>
#       <td>조 바이든\n</td>
#     </tr>
#     <tr>
#       <td><img src="https://storage.googleapis.com/lge_tv/human_images/image_22.jpeg" width="40%"/></td>
#       <td>모름\n</td>
#       <td>이름을 확인하기 위해 검색을 해보겠습니다.\n강호동\n</td>
#       <td>모름\n</td>
#     </tr>
#     <tr>
#       <td><img src="https://storage.googleapis.com/lge_tv/human_images/image_23.jpeg" width="40%"/></td>
#       <td>시진핑\n</td>
#       <td>시진핑\n</td>
#       <td>시진핑\n</td>
#     </tr>
#     <tr>
#       <td><img src="https://storage.googleapis.com/lge_tv/human_images/image_24.jpeg" width="40%"/></td>
#       <td>강호동\n</td>
#       <td>강호동\n</td>
#       <td>강호동\n</td>
#     </tr>
#     <tr>
#       <td><img src="https://storage.googleapis.com/lge_tv/human_images/image_25.jpeg" width="40%"/></td>
#       <td>모름\n</td>
#       <td>모름\n</td>
#       <td>모름\n</td>
#     </tr>
#     <tr>
#       <td><img src="https://storage.googleapis.com/lge_tv/human_images/image_26.jpeg" width="40%"/></td>
#       <td>유재석\n</td>
#       <td>유재석\n</td>
#       <td>유재석\n</td>
#     </tr>
#     <tr>
#       <td><img src="https://storage.googleapis.com/lge_tv/human_images/image_27.jpeg" width="40%"/></td>
#       <td>김선호\n</td>
#       <td>김선호\n</td>
#       <td>김선호\n</td>
#     </tr>
#     <tr>
#       <td><img src="https://storage.googleapis.com/lge_tv/human_images/image_28.jpeg" width="40%"/></td>
#       <td>유아인\n</td>
#       <td>유아인\n</td>
#       <td>유아인\n</td>
#     </tr>
#     <tr>
#       <td><img src="https://storage.googleapis.com/lge_tv/human_images/image_29.jpeg" width="40%"/></td>
#       <td>전현무\n</td>
#       <td>전현무\n</td>
#       <td>전현무\n</td>
#     </tr>
#     <tr>
#       <td><img src="https://storage.googleapis.com/lge_tv/human_images/image_30.jpeg" width="40%"/></td>
#       <td>제니퍼 로페즈\n</td>
#       <td>제니퍼 로페즈\n</td>
#       <td>제니퍼 로페즈\n</td>
#     </tr>
#     <tr>
#       <td><img src="https://storage.googleapis.com/lge_tv/human_images/image_31.jpeg" width="40%"/></td>
#       <td>싸이, 손연재, 류승룡\n</td>
#       <td>싸이, 손연재, 류승룡\n</td>
#       <td>싸이, 손연재, 류승룡\n</td>
#     </tr>
#     <tr>
#       <td><img src="https://storage.googleapis.com/lge_tv/human_images/image_32.jpeg" width="40%"/></td>
#       <td>모름</td>
#       <td>모름\n</td>
#       <td>모름\n</td>
#     </tr>
#     <tr>
#       <td><img src="https://storage.googleapis.com/lge_tv/human_images/image_33.jpeg" width="40%"/></td>
#       <td>버락 오바마\n</td>
#       <td>버락 오바마\n</td>
#       <td>버락 오바마\n</td>
#     </tr>
#     <tr>
#       <td><img src="https://storage.googleapis.com/lge_tv/human_images/image_34.jpeg" width="40%"/></td>
#       <td>모름\n</td>
#       <td>모름\n</td>
#       <td>모름\n</td>
#     </tr>
#     <tr>
#       <td><img src="https://storage.googleapis.com/lge_tv/human_images/image_35.jpeg" width="40%"/></td>
#       <td>전지현\n</td>
#       <td>전지현\n</td>
#       <td>전지현\n</td>
#     </tr>
#     <tr>
#       <td><img src="https://storage.googleapis.com/lge_tv/human_images/image_36.jpeg" width="40%"/></td>
#       <td>유아인\n</td>
#       <td>유아인\n</td>
#       <td>유아인\n</td>
#     </tr>
#     <tr>
#       <td><img src="https://storage.googleapis.com/lge_tv/human_images/image_37.jpeg" width="40%"/></td>
#       <td>Warren Buffett\n</td>
#       <td>워렌 버핏\n</td>
#       <td>워렌 버핏\n</td>
#     </tr>
#     <tr>
#       <td><img src="https://storage.googleapis.com/lge_tv/human_images/image_38.jpeg" width="40%"/></td>
#       <td>모름\n</td>
#       <td>모름\n</td>
#       <td>저우둥위 (周冬雨)\n</td>
#     </tr>
#     <tr>
#       <td><img src="https://storage.googleapis.com/lge_tv/human_images/image_39.jpeg" width="40%"/></td>
#       <td>한소희\n</td>
#       <td>한소희\n</td>
#       <td>한소희\n</td>
#     </tr>
#     <tr>
#       <td><img src="https://storage.googleapis.com/lge_tv/human_images/image_40.jpeg" width="40%"/></td>
#       <td>패리스 힐튼\n</td>
#       <td>파리스 힐튼\n</td>
#       <td>파리스 힐튼\n</td>
#     </tr>
#     <tr>
#       <td><img src="https://storage.googleapis.com/lge_tv/human_images
