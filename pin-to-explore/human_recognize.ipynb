# %% [markdown]
# # Gemini Human Recognize

# %%
# %pip install --upgrade --quiet google-genai pillow dotenv
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv
import os

load_dotenv()
# Out:
# True

# %%
PROJECT_ID = os.environ['PROJECT_ID']
LOCATION = os.environ['LOCATION']
BUCKET = os.environ['BUCKET']

# %%
MODEL_ID= "gemini-2.0-flash-001"

# %%
from google import genai
from google.genai import types
from google.genai.types import (
    GenerateContentConfig,
    GoogleSearch,
    Part,
    Tool,
)
from IPython.display import HTML, Markdown, display

# %%
client = genai.Client(vertexai=True, project=PROJECT_ID, location=LOCATION)

# %%
def detect_with_gemini(image_path):
    system_instruction="You are an image analysis AI. You can identify people in images and provide their names"

    google_search_tool = Tool(google_search=GoogleSearch())

    grounding_config = GenerateContentConfig(
        temperature = 0.1,
        top_p = 0.99,
        max_output_tokens = 8192,
        response_modalities = ["TEXT"],
        system_instruction=system_instruction,
        tools=[google_search_tool]   
    )

    prompt = f"""If you can identify the people in the image, provide their names. If you cannot identify a person in the image, respond with 'unknown'. Avoid adding description"""

    with open(image_path, "rb") as f:
        image = f.read()

    response = client.models.generate_content(
        model=MODEL_ID,
        contents=[Part.from_bytes(data=image, mime_type="image/png"),
            prompt,],
        config=grounding_config
    )

    print(response.text)

# %% [markdown]
# ## Vision

# %%
# %pip install google-cloud-vision

# %%
from google.cloud import vision

# %%
vision_client = vision.ImageAnnotatorClient()

# %%
def detect_with_vision(image_path):
    with open(image_path, "rb") as f:
        image = f.read()
    vision_image = vision.Image(content=image)
    web_detection = vision_client.web_detection(image=vision_image).web_detection
    results = [d.description for d in web_detection.web_entities]
    print(results)

# %% [markdown]
# <img src=./human1.png width="10%">

# %%
detect_with_gemini("human1.png")
# Out:
# Based on the image, the people are Guo Wengui and Kim Jung-ju.
# The people in the image are Guo Wengui and Kim Jung-ju.

# %%
detect_with_vision("human1.png")
# Out:
# ['Myung Tae-kyun', 'Yoon Suk Yeol', 'Newstapa', '2024 South Korean martial law crisis', 'Journalism', 'People Power Party', 'Investigative journalism', 'Korea exploration Journalism Center', 'Reporter', 'Mayor of Seoul']

# %% [markdown]
# <img src=./human3.png width="10%">

# %%
detect_with_gemini("human3.png")
# Out:
# Based on the search results, the cast of "The Player 2: Master of Swindlers" includes:
#
# *   Song Seung-heon
# *   Oh Yeon-seo
# *   Tae Won-seok
# *   Lee Si-eon
# *   Jang Gyu-ri
#
# I am unable to identify the people in the image with certainty, but they may be members of the cast listed above.

# %%
detect_with_vision("human3.png")
# Out:
# ['Lee Yi-kyung', 'Song Eun-yi', 'Kwon Il-yong', 'Ahn Jung-hwan', 'Brave Detectives', 'The Detectives', 'Detective', 'Criminal investigation', 'Television', 'MyDramaList']

# %% [markdown]
# <img src=./human5.png width="10%">

# %%
detect_with_gemini("human5.png")
# Out:
# From left to right, the people in the image are: Kim Jin-pyo, Lee Jae-myung, and Park Byeong-seug.

# %%
detect_with_vision("human5.png")
# Out:
# ['Kim Bu-gyeom', 'Politics', 'Minister', 'Member of the National Assembly of the Republic of Korea', '2020 South Korean legislative election', 'General election', 'Kyunghyang Shinmun', 'Election law']

# %% [markdown]
# <img src="./human4.png" width="10%">

# %%
detect_with_gemini("human4.png")
# Out:
# Based on the image, the people in the image are likely the hosts of the South Korean show "Please Take Care of My Refrigerator". I am unable to provide their specific names.

# %%
detect_with_vision("human4.png")
# Out:
# ['Kim Seong-joo', 'Please Take Care of My Refrigerator', 'Lee Yeon-bok', 'JTBC', 'Variety show', 'Television', 'Refrigerator', 'Netflix', '', 'MyDramaList']

# %% [markdown]
# <img src=./human6.png width="10%">

# %%
detect_with_gemini("human6.png")
# Out:
# The people in the image are Lee Sun-kyun and IU.

# %%
detect_with_vision("human6.png")
# Out:
# ['IU', 'Lee Sun-kyun', 'My Mister', 'Times Square, Seoul', '데일리안', 'tvN', 'Actor', 'Photograph', 'Laughter', 'tvN DRAMA']
